# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('Data/quotes_dataset.csv', low_memory=False) #Reading the raw dataset

# %%
df = df.iloc[: , :3] #Keeping only the first three columns ( Quote, Author and Tags)

# %%
df.columns = ['quote','authorOrigin','tags'] #Naming the columns

# %%
df[0:5]
# Out:
#                                                                                                                                                    quote  \
# 0  You've gotta dance like there's nobody watching,Love like you'll never be hurt,Sing like there's nobody listening,And live like it's heaven on earth.
# 1                                                 You know you're in love when you can't fall asleep because reality is finally better than your dreams.
# 2                                                                                       A friend is someone who knows all about you and still loves you.
# 3                                         Darkness cannot drive out darkness: only light can do that. Hate cannot drive out hate: only love can do that.
# 4                                                                                                                We accept the love we think we deserve.
#
# ...

# %%
df.to_csv('Data/cleanedData.csv')

# %%
df[0:50] # First 50 quotes
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
